# %%
# %run ptycho_reconstruct.py
# Out:
# using GPU
# loaded data, memory used, and total: 80896 82432
# normalized by data.nbytes memory used and total normalized: 1.234375 1.2578125
# data size 65536
# ----
# Split and Overlap, memory used, and total: 80896 82432
# normalized by data.nbytes memory used and total normalized: 1.234375 1.2578125
# data size 65536
# ----
# geometry: img size: (37, 37) frames: (16, 16, 64)
# not refining illumination, starting with good one, maxiter: 300
# start AP memory used, and total: 257536 501760
# normalized by data.nbytes memory used and total normalized: 3.9296875 7.65625
# data size 65536
# ----
# after Prox_data, memory used, and total: 259072 632832
# normalized by data.nbytes memory used and total normalized: 3.953125 9.65625
# ----
# after frames initial, memory used, and total: 390144 763904
# normalized by data.nbytes memory used and total normalized: 5.953125 11.65625
# ----
# !!!frames_norm (7.402797+0j) (7.402797+0j)
# start loop, memory used, and total: 538624 894976
# normalized by data.nbytes memory used and total normalized: 8.21875 13.65625
# ----
# 0
# Here <class 'cupy.ndarray'> complex64
# 1
# Here <class 'cupy.ndarray'> complex64
# 2
# Here <class 'cupy.ndarray'> complex64
# 3
# Here <class 'cupy.ndarray'> complex64
# 4
# Here <class 'cupy.ndarray'> complex64
# 5
# Here <class 'cupy.ndarray'> complex64
# 6
# Here <class 'cupy.ndarray'> complex64
# 7
# Here <class 'cupy.ndarray'> complex64
# 8
# Here <class 'cupy.ndarray'> complex64
# 9
# Here <class 'cupy.ndarray'> complex64
# 10
# Here <class 'cupy.ndarray'> complex64
# 11
# Here <class 'cupy.ndarray'> complex64
# 12
# Here <class 'cupy.ndarray'> complex64
# 13
# Here <class 'cupy.ndarray'> complex64
# 14
# Here <class 'cupy.ndarray'> complex64
# 15
# Here <class 'cupy.ndarray'> complex64
# 16
# Here <class 'cupy.ndarray'> complex64
# 17
# Here <class 'cupy.ndarray'> complex64
# 18
# Here <class 'cupy.ndarray'> complex64
# 19
# Here <class 'cupy.ndarray'> complex64
# 20
# Here <class 'cupy.ndarray'> complex64
# 21
# Here <class 'cupy.ndarray'> complex64
# 22
# Here <class 'cupy.ndarray'> complex64
# 23
# Here <class 'cupy.ndarray'> complex64
# 24
# Here <class 'cupy.ndarray'> complex64
# 25
# Here <class 'cupy.ndarray'> complex64
# 26
# Here <class 'cupy.ndarray'> complex64
# 27
# Here <class 'cupy.ndarray'> complex64
# 28
# Here <class 'cupy.ndarray'> complex64
# 29
# Here <class 'cupy.ndarray'> complex64
# 30
# Here <class 'cupy.ndarray'> complex64
# 31
# Here <class 'cupy.ndarray'> complex64
# 32
# Here <class 'cupy.ndarray'> complex64
# 33
# Here <class 'cupy.ndarray'> complex64
# 34
# Here <class 'cupy.ndarray'> complex64
# 35
# Here <class 'cupy.ndarray'> complex64
# 36
# Here <class 'cupy.ndarray'> complex64
# 37
# Here <class 'cupy.ndarray'> complex64
# 38
# Here <class 'cupy.ndarray'> complex64
# 39
# Here <class 'cupy.ndarray'> complex64
# 40
# Here <class 'cupy.ndarray'> complex64
# 41
# Here <class 'cupy.ndarray'> complex64
# 42
# Here <class 'cupy.ndarray'> complex64
# 43
# Here <class 'cupy.ndarray'> complex64
# 44
# Here <class 'cupy.ndarray'> complex64
# 45
# Here <class 'cupy.ndarray'> complex64
# 46
# Here <class 'cupy.ndarray'> complex64
# 47
# Here <class 'cupy.ndarray'> complex64
# 48
# Here <class 'cupy.ndarray'> complex64
# 49
# Here <class 'cupy.ndarray'> complex64
# 50
# Here <class 'cupy.ndarray'> complex64
# 51
# Here <class 'cupy.ndarray'> complex64
# 52
# Here <class 'cupy.ndarray'> complex64
# 53
# Here <class 'cupy.ndarray'> complex64
# 54
# Here <class 'cupy.ndarray'> complex64
# 55
# Here <class 'cupy.ndarray'> complex64
# 56
# Here <class 'cupy.ndarray'> complex64
# 57
# Here <class 'cupy.ndarray'> complex64
# 58
# Here <class 'cupy.ndarray'> complex64
# 59
# Here <class 'cupy.ndarray'> complex64
# 60
# Here <class 'cupy.ndarray'> complex64
# 61
# Here <class 'cupy.ndarray'> complex64
# 62
# Here <class 'cupy.ndarray'> complex64
# 63
# Here <class 'cupy.ndarray'> complex64
# 64
# Here <class 'cupy.ndarray'> complex64
# 65
# Here <class 'cupy.ndarray'> complex64
# 66
# Here <class 'cupy.ndarray'> complex64
# 67
# Here <class 'cupy.ndarray'> complex64
# 68
# Here <class 'cupy.ndarray'> complex64
# 69
# Here <class 'cupy.ndarray'> complex64
# 70
# Here <class 'cupy.ndarray'> complex64
# 71
# Here <class 'cupy.ndarray'> complex64
# 72
# Here <class 'cupy.ndarray'> complex64
# 73
# Here <class 'cupy.ndarray'> complex64
# 74
# Here <class 'cupy.ndarray'> complex64
# 75
# Here <class 'cupy.ndarray'> complex64
# 76
# Here <class 'cupy.ndarray'> complex64
# 77
# Here <class 'cupy.ndarray'> complex64
# 78
# Here <class 'cupy.ndarray'> complex64
# 79
# Here <class 'cupy.ndarray'> complex64
# 80
# Here <class 'cupy.ndarray'> complex64
# 81
# Here <class 'cupy.ndarray'> complex64
# 82
# Here <class 'cupy.ndarray'> complex64
# 83
# Here <class 'cupy.ndarray'> complex64
# 84
# Here <class 'cupy.ndarray'> complex64
# 85
# Here <class 'cupy.ndarray'> complex64
# 86
# Here <class 'cupy.ndarray'> complex64
# 87
# Here <class 'cupy.ndarray'> complex64
# 88
# Here <class 'cupy.ndarray'> complex64
# 89
# Here <class 'cupy.ndarray'> complex64
# 90
# Here <class 'cupy.ndarray'> complex64
# 91
# Here <class 'cupy.ndarray'> complex64
# 92
# Here <class 'cupy.ndarray'> complex64
# 93
# Here <class 'cupy.ndarray'> complex64
# 94
# Here <class 'cupy.ndarray'> complex64
# 95
# Here <class 'cupy.ndarray'> complex64
# 96
# Here <class 'cupy.ndarray'> complex64
# 97
# Here <class 'cupy.ndarray'> complex64
# 98
# Here <class 'cupy.ndarray'> complex64
# 99
# Here <class 'cupy.ndarray'> complex64
# 100
# Here <class 'cupy.ndarray'> complex64
# 101
# Here <class 'cupy.ndarray'> complex64
# 102
# Here <class 'cupy.ndarray'> complex64
# 103
# Here <class 'cupy.ndarray'> complex64
# 104
# Here <class 'cupy.ndarray'> complex64
# 105
# Here <class 'cupy.ndarray'> complex64
# 106
# Here <class 'cupy.ndarray'> complex64
# 107
# Here <class 'cupy.ndarray'> complex64
# 108
# Here <class 'cupy.ndarray'> complex64
# 109
# Here <class 'cupy.ndarray'> complex64
# 110
# Here <class 'cupy.ndarray'> complex64
# 111
# Here <class 'cupy.ndarray'> complex64
# 112
# Here <class 'cupy.ndarray'> complex64
# 113
# Here <class 'cupy.ndarray'> complex64
# 114
# Here <class 'cupy.ndarray'> complex64
# 115
# Here <class 'cupy.ndarray'> complex64
# 116
# Here <class 'cupy.ndarray'> complex64
# 117
# Here <class 'cupy.ndarray'> complex64
# 118
# Here <class 'cupy.ndarray'> complex64
# 119
# Here <class 'cupy.ndarray'> complex64
# 120
# Here <class 'cupy.ndarray'> complex64
# 121
# Here <class 'cupy.ndarray'> complex64
# 122
# Here <class 'cupy.ndarray'> complex64
# 123
# Here <class 'cupy.ndarray'> complex64
# 124
# Here <class 'cupy.ndarray'> complex64
# 125
# Here <class 'cupy.ndarray'> complex64
# 126
# Here <class 'cupy.ndarray'> complex64
# 127
# Here <class 'cupy.ndarray'> complex64
# 128
# Here <class 'cupy.ndarray'> complex64
# 129
# Here <class 'cupy.ndarray'> complex64
# 130
# Here <class 'cupy.ndarray'> complex64
# 131
# Here <class 'cupy.ndarray'> complex64
# 132
# Here <class 'cupy.ndarray'> complex64
# 133
# Here <class 'cupy.ndarray'> complex64
# 134
# Here <class 'cupy.ndarray'> complex64
# 135
# Here <class 'cupy.ndarray'> complex64
# 136
# Here <class 'cupy.ndarray'> complex64
# 137
# Here <class 'cupy.ndarray'> complex64
# 138
# Here <class 'cupy.ndarray'> complex64
# 139
# Here <class 'cupy.ndarray'> complex64
# 140
# Here <class 'cupy.ndarray'> complex64
# 141
# Here <class 'cupy.ndarray'> complex64
# 142
# Here <class 'cupy.ndarray'> complex64
# 143
# Here <class 'cupy.ndarray'> complex64
# 144
# Here <class 'cupy.ndarray'> complex64
# 145
# Here <class 'cupy.ndarray'> complex64
# 146
# Here <class 'cupy.ndarray'> complex64
# 147
# Here <class 'cupy.ndarray'> complex64
# 148
# Here <class 'cupy.ndarray'> complex64
# 149
# Here <class 'cupy.ndarray'> complex64
# 150
# Here <class 'cupy.ndarray'> complex64
# 151
# Here <class 'cupy.ndarray'> complex64
# 152
# Here <class 'cupy.ndarray'> complex64
# 153
# Here <class 'cupy.ndarray'> complex64
# 154
# Here <class 'cupy.ndarray'> complex64
# 155
# Here <class 'cupy.ndarray'> complex64
# 156
# Here <class 'cupy.ndarray'> complex64
# 157
# Here <class 'cupy.ndarray'> complex64
# 158
# Here <class 'cupy.ndarray'> complex64
# 159
# Here <class 'cupy.ndarray'> complex64
# 160
# Here <class 'cupy.ndarray'> complex64
# 161
# Here <class 'cupy.ndarray'> complex64
# 162
# Here <class 'cupy.ndarray'> complex64
# 163
# Here <class 'cupy.ndarray'> complex64
# 164
# Here <class 'cupy.ndarray'> complex64
# 165
# Here <class 'cupy.ndarray'> complex64
# 166
# Here <class 'cupy.ndarray'> complex64
# 167
# Here <class 'cupy.ndarray'> complex64
# 168
# Here <class 'cupy.ndarray'> complex64
# 169
# Here <class 'cupy.ndarray'> complex64
# 170
# Here <class 'cupy.ndarray'> complex64
# 171
# Here <class 'cupy.ndarray'> complex64
# 172
# Here <class 'cupy.ndarray'> complex64
# 173
# Here <class 'cupy.ndarray'> complex64
# 174
# Here <class 'cupy.ndarray'> complex64
# 175
# Here <class 'cupy.ndarray'> complex64
# 176
# Here <class 'cupy.ndarray'> complex64
# 177
# Here <class 'cupy.ndarray'> complex64
# 178
# Here <class 'cupy.ndarray'> complex64
# 179
# Here <class 'cupy.ndarray'> complex64
# 180
# Here <class 'cupy.ndarray'> complex64
# 181
# Here <class 'cupy.ndarray'> complex64
# 182
# Here <class 'cupy.ndarray'> complex64
# 183
# Here <class 'cupy.ndarray'> complex64
# 184
# Here <class 'cupy.ndarray'> complex64
# 185
# Here <class 'cupy.ndarray'> complex64
# 186
# Here <class 'cupy.ndarray'> complex64
# 187
# Here <class 'cupy.ndarray'> complex64
# 188
# Here <class 'cupy.ndarray'> complex64
# 189
# Here <class 'cupy.ndarray'> complex64
# 190
# Here <class 'cupy.ndarray'> complex64
# 191
# Here <class 'cupy.ndarray'> complex64
# 192
# Here <class 'cupy.ndarray'> complex64
# 193
# Here <class 'cupy.ndarray'> complex64
# 194
# Here <class 'cupy.ndarray'> complex64
# 195
# Here <class 'cupy.ndarray'> complex64
# 196
# Here <class 'cupy.ndarray'> complex64
# 197
# Here <class 'cupy.ndarray'> complex64
# 198
# Here <class 'cupy.ndarray'> complex64
# 199
# Here <class 'cupy.ndarray'> complex64
# 200
# Here <class 'cupy.ndarray'> complex64
# 201
# Here <class 'cupy.ndarray'> complex64
# 202
# Here <class 'cupy.ndarray'> complex64
# 203
# Here <class 'cupy.ndarray'> complex64
# 204
# Here <class 'cupy.ndarray'> complex64
# 205
# Here <class 'cupy.ndarray'> complex64
# 206
# Here <class 'cupy.ndarray'> complex64
# 207
# Here <class 'cupy.ndarray'> complex64
# 208
# Here <class 'cupy.ndarray'> complex64
# 209
# Here <class 'cupy.ndarray'> complex64
# 210
# Here <class 'cupy.ndarray'> complex64
# 211
# Here <class 'cupy.ndarray'> complex64
# 212
# Here <class 'cupy.ndarray'> complex64
# 213
# Here <class 'cupy.ndarray'> complex64
# 214
# Here <class 'cupy.ndarray'> complex64
# 215
# Here <class 'cupy.ndarray'> complex64
# 216
# Here <class 'cupy.ndarray'> complex64
# 217
# Here <class 'cupy.ndarray'> complex64
# 218
# Here <class 'cupy.ndarray'> complex64
# 219
# Here <class 'cupy.ndarray'> complex64
# 220
# Here <class 'cupy.ndarray'> complex64
# 221
# Here <class 'cupy.ndarray'> complex64
# 222
# Here <class 'cupy.ndarray'> complex64
# 223
# Here <class 'cupy.ndarray'> complex64
# 224
# Here <class 'cupy.ndarray'> complex64
# 225
# Here <class 'cupy.ndarray'> complex64
# 226
# Here <class 'cupy.ndarray'> complex64
# 227
# Here <class 'cupy.ndarray'> complex64
# 228
# Here <class 'cupy.ndarray'> complex64
# 229
# Here <class 'cupy.ndarray'> complex64
# 230
# Here <class 'cupy.ndarray'> complex64
# 231
# Here <class 'cupy.ndarray'> complex64
# 232
# Here <class 'cupy.ndarray'> complex64
# 233
# Here <class 'cupy.ndarray'> complex64
# 234
# Here <class 'cupy.ndarray'> complex64
# 235
# Here <class 'cupy.ndarray'> complex64
# 236
# Here <class 'cupy.ndarray'> complex64
# 237
# Here <class 'cupy.ndarray'> complex64
# 238
# Here <class 'cupy.ndarray'> complex64
# 239
# Here <class 'cupy.ndarray'> complex64
# 240
# Here <class 'cupy.ndarray'> complex64
# 241
# Here <class 'cupy.ndarray'> complex64
# 242
# Here <class 'cupy.ndarray'> complex64
# 243
# Here <class 'cupy.ndarray'> complex64
# 244
# Here <class 'cupy.ndarray'> complex64
# 245
# Here <class 'cupy.ndarray'> complex64
# 246
# Here <class 'cupy.ndarray'> complex64
# 247
# Here <class 'cupy.ndarray'> complex64
# 248
# Here <class 'cupy.ndarray'> complex64
# 249
# Here <class 'cupy.ndarray'> complex64
# 250
# Here <class 'cupy.ndarray'> complex64
# 251
# Here <class 'cupy.ndarray'> complex64
# 252
# Here <class 'cupy.ndarray'> complex64
# 253
# Here <class 'cupy.ndarray'> complex64
# 254
# Here <class 'cupy.ndarray'> complex64
# 255
# Here <class 'cupy.ndarray'> complex64
# 256
# Here <class 'cupy.ndarray'> complex64
# 257
# Here <class 'cupy.ndarray'> complex64
# 258
# Here <class 'cupy.ndarray'> complex64
# 259
# Here <class 'cupy.ndarray'> complex64
# 260
# Here <class 'cupy.ndarray'> complex64
# 261
# Here <class 'cupy.ndarray'> complex64
# 262
# Here <class 'cupy.ndarray'> complex64
# 263
# Here <class 'cupy.ndarray'> complex64
# 264
# Here <class 'cupy.ndarray'> complex64
# 265
# Here <class 'cupy.ndarray'> complex64
# 266
# Here <class 'cupy.ndarray'> complex64
# 267
# Here <class 'cupy.ndarray'> complex64
# 268
# Here <class 'cupy.ndarray'> complex64
# 269
# Here <class 'cupy.ndarray'> complex64
# 270
# Here <class 'cupy.ndarray'> complex64
# 271
# Here <class 'cupy.ndarray'> complex64
# 272
# Here <class 'cupy.ndarray'> complex64
# 273
# Here <class 'cupy.ndarray'> complex64
# 274
# Here <class 'cupy.ndarray'> complex64
# 275
# Here <class 'cupy.ndarray'> complex64
# 276
# Here <class 'cupy.ndarray'> complex64
# 277
# Here <class 'cupy.ndarray'> complex64
# 278
# Here <class 'cupy.ndarray'> complex64
# 279
# Here <class 'cupy.ndarray'> complex64
# 280
# Here <class 'cupy.ndarray'> complex64
# 281
# Here <class 'cupy.ndarray'> complex64
# 282
# Here <class 'cupy.ndarray'> complex64
# 283
# Here <class 'cupy.ndarray'> complex64
# 284
# Here <class 'cupy.ndarray'> complex64
# 285
# Here <class 'cupy.ndarray'> complex64
# 286
# Here <class 'cupy.ndarray'> complex64
# 287
# Here <class 'cupy.ndarray'> complex64
# 288
# Here <class 'cupy.ndarray'> complex64
# 289
# Here <class 'cupy.ndarray'> complex64
# 290
# Here <class 'cupy.ndarray'> complex64
# 291
# Here <class 'cupy.ndarray'> complex64
# 292
# Here <class 'cupy.ndarray'> complex64
# 293
# Here <class 'cupy.ndarray'> complex64
# 294
# Here <class 'cupy.ndarray'> complex64
# 295
# Here <class 'cupy.ndarray'> complex64
# 296
# Here <class 'cupy.ndarray'> complex64
# 297
# Here <class 'cupy.ndarray'> complex64
# 298
# Here <class 'cupy.ndarray'> complex64
# 299
# Here <class 'cupy.ndarray'> complex64
# end of loop, memory used, and total/1e9: 0.000685568 0.001222656
# normalized by data.nbytes memory used and total normalized: 10.4609375 18.65625
# ----
# total time: 4.2996304258704185
# {'Overlap': 0, 'Split': 0, 'Prox_data': 0.01359131745994091, 'Data_prox_tot': 0.49945252481848, 'Propagate': 0.43503973772749305, 'mse_data': 0.05027138954028487, 'Gramiam': 0.00011125672608613968, 'Gramiam_completion': 0, 'Precondition': 0, 'Eigensolver': 3.0357322967611253, 'Sync_setup': 7.430091500282288e-05, 'fd': 0}
# total time operators benchmarked: 4.034272823948413
# after normalization
# {'Overlap': 0.0, 'Split': 0.0, 'Prox_data': 0.0033689633926737884, 'Data_prox_tot': 0.12380236702228213, 'Propagate': 0.10783597359727201, 'mse_data': 0.012461078299380701, 'Gramiam': 2.7577888492244008e-05, 'Gramiam_completion': 0.0, 'Precondition': 0.0, 'Eigensolver': 0.752485622375435, 'Sync_setup': 1.841742446414501e-05, 'fd': 0.0}
# solver timers:
#  {'solver_tot': 4.299504522234201, 'solver_loop': 4.162570415996015, 'ProxD': 0.5621914933435619, 'Overlap': 0.040617089718580246, 'Sync': 3.3017026148736477, 'illuminate&split': 0.01983200153335929, 'refine_illumination': 7.924158126115799e-05, 'mse_step': 0.07639539521187544, 'mse_truth': 0.1253448254428804, 'copies': 0.017450602259486914, 'loop_intrnl': 4.144869152456522, 'solver_final': 0.005724958144128323, 'solver_init': 0.13120550522580743}
# solver timers after normalization by 4.162570415996015 :
#  {'solver_tot': 1.0328965260772462, 'solver_loop': 1.0, 'ProxD': 0.1350587346662438, 'Overlap': 0.009757694323319077, 'Sync': 0.7931884112244189, 'illuminate&split': 0.00476436421523308, 'refine_illumination': 1.9036694480085366e-05, 'mse_step': 0.01835293762678502, 'mse_truth': 0.030112361573801275, 'copies': 0.00419226595961653, 'loop_intrnl': 0.9957475161329475, 'solver_final': 0.0013753420535850469, 'solver_init': 0.03152030887492211}
# mse timings: 0.09873668874087116
# ops timings: 0.15379209585889256
# solver timers after normalization by total prox ops 0.15379209585889256 :
#  {'solver_tot': 6.716187332702392, 'solver_loop': 6.502284752771175, 'ProxD': 0.8781903511488848, 'Overlap': 0.06344730702071948, 'Sync': 5.1575369123793315, 'illuminate&split': 0.03097925279335866, 'refine_illumination': 0.00012378200826102225, 'mse_step': 0.11933602649920462, 'mse_truth': 0.19579914953126065, 'copies': 0.02725930702877618, 'loop_intrnl': 6.474633891761034, 'solver_final': 0.008942865664871047, 'solver_init': 0.204954023800044}
# solver tot (seconds) : 4.299504522234201 loop: 4.162570415996015 seconds
# proxD : 13.50587346662438 %
# Overlap : 0.9757694323319077 %
# illuminate and split : 0.47643642152330795 %
# mse: 6.054230559718703 %
# proxD (propagate(ffts), mse, prox)%: (87.10332135884245, 10.065298910753409, 2.721243118128297)

# %%
# %run ptycho_simulate.py
# Out:
# type0 <class 'cupy.ndarray'> int64
# <class 'cupy.ndarray'>
# (22, 22)
# !!! (25, 16, 16)
# 9.4120935e-07
# 16 16 22 22
# [[0.8847456 +0.05343042j 0.81804085+0.08043875j 0.9267165 +0.0349523j
#   0.9555254 +0.02161676j 0.8847456 +0.05343042j]
#  [0.83106196+0.07539716j 0.80517757+0.08530804j 0.94103754+0.02838911j
#   0.9701812 +0.01463083j 0.89857155+0.0474687j ]
#  [0.73124987+0.11111129j 0.83106196+0.07539716j 0.91256154+0.04131073j
#   0.9701812 +0.01463083j 0.91256154+0.04131073j]
#  [0.74318963+0.10719916j 0.75528044+0.10313633j 0.91256154+0.04131073j
#   0.9701812 +0.01463083j 0.8847456 +0.05343042j]
#  [0.81804085+0.08043875j 0.75528044+0.10313633j 0.83106196+0.07539716j
#   0.9555254 +0.02161676j 0.89857155+0.0474687j ]]
# [[-0.11771791-0.00710907j  0.0297182 -0.0963385j   0.21124229-0.20202743j
#    0.11364844-0.03619557j -0.09224197+0.16781563j]
#  [ 0.01130939+0.1017231j   0.1243073 +0.01317028j  0.27952102-0.10988846j
#    0.15094851+0.00399395j -0.06239428+0.15997678j]
#  [ 0.13530332+0.18984565j  0.23423354+0.12650812j  0.2975263 +0.01346871j
#    0.13423279+0.03112061j -0.05467243+0.06543599j]
#  [ 0.08336489+0.04278826j  0.11771524+0.01471271j  0.1279119 -0.02162767j
#   -0.01768247-0.00026666j -0.10036507-0.07555795j]
#  [-0.05993463-0.16716918j -0.02652695-0.14302884j -0.04139631-0.06598308j
#   -0.11460237+0.07222948j -0.06585432-0.00347888j]]

# %%
# %run ptycho_simulate.py
# Out:
# type0 <class 'cupy.ndarray'> int64
# <class 'cupy.ndarray'>
# (37, 37)
# !!! (64, 16, 16)
# 1.5650087e-06
# 16 16 37 37
# [[0.9267165 +0.0349523j  0.91256154+0.04131073j 0.89857155+0.0474687j
#   0.89857155+0.0474687j  0.8710827 +0.05920008j]
#  [0.91256154+0.04131073j 0.91256154+0.04131073j 0.8847456 +0.05343042j
#   0.91256154+0.04131073j 0.89857155+0.0474687j ]
#  [0.9701812 +0.01463083j 0.8847456 +0.05343042j 0.91256154+0.04131073j
#   0.91256154+0.04131073j 0.89857155+0.0474687j ]
#  [0.9555254 +0.02161676j 0.8847456 +0.05343042j 0.9267165 +0.0349523j
#   0.8710827 +0.05920008j 0.8847456 +0.05343042j]
#  [0.9701812 +0.01463083j 0.89857155+0.0474687j  0.8847456 +0.05343042j
#   0.91256154+0.04131073j 0.89857155+0.0474687j ]]
# [[-0.12330227-0.0046505j   0.02733272-0.10865685j  0.20789912-0.19291256j
#    0.10797501-0.03083501j -0.0921052 +0.1646143j ]
#  [ 0.01740347+0.11068201j  0.14088577+0.00637776j  0.26615936-0.0954738j
#    0.14193483+0.00804375j -0.06239428+0.15997678j]
#  [ 0.20955938+0.22274174j  0.25273547+0.12681022j  0.2975263 +0.01346871j
#    0.12543459+0.03309641j -0.05433864+0.06404879j]
#  [ 0.11189532+0.04129803j  0.13777395+0.0067486j   0.1296861 -0.02293471j
#   -0.0158763 -0.00107898j -0.10036507-0.07555795j]
#  [-0.08685219-0.19079123j -0.0451919 -0.16566022j -0.04606344-0.06872774j
#   -0.11106685+0.06653978j -0.06585432-0.00347888j]]

# %%
# %run ptycho_reconstruct.py
# Out:
# using GPU
# loaded data, memory used, and total: 80896 82432
# normalized by data.nbytes memory used and total normalized: 1.234375 1.2578125
# data size 65536
# ----
# Split and Overlap, memory used, and total: 80896 82432
# normalized by data.nbytes memory used and total normalized: 1.234375 1.2578125
# data size 65536
# ----
# geometry: img size: (37, 37) frames: (16, 16, 64)
# not refining illumination, starting with good one, maxiter: 30
# start AP memory used, and total: 214528 263680
# normalized by data.nbytes memory used and total normalized: 3.2734375 4.0234375
# data size 65536
# ----
# after Prox_data, memory used, and total: 216064 394752
# normalized by data.nbytes memory used and total normalized: 3.296875 6.0234375
# ----
# after frames initial, memory used, and total: 347136 525824
# normalized by data.nbytes memory used and total normalized: 5.296875 8.0234375
# ----
# !!!frames_norm (7.402797+0j) (7.402797+0j)
# start loop, memory used, and total: 491008 656896
# normalized by data.nbytes memory used and total normalized: 7.4921875 10.0234375
# ----
# 0
# Here <class 'cupy.ndarray'> complex64
# 1
# Here <class 'cupy.ndarray'> complex64
# 2
# Here <class 'cupy.ndarray'> complex64
# 3
# Here <class 'cupy.ndarray'> complex64
# 4
# Here <class 'cupy.ndarray'> complex64
# 5
# Here <class 'cupy.ndarray'> complex64
# 6
# Here <class 'cupy.ndarray'> complex64
# 7
# Here <class 'cupy.ndarray'> complex64
# 8
# Here <class 'cupy.ndarray'> complex64
# 9
# Here <class 'cupy.ndarray'> complex64
# 10
# Here <class 'cupy.ndarray'> complex64
# 11
# Here <class 'cupy.ndarray'> complex64
# 12
# Here <class 'cupy.ndarray'> complex64
# 13
# Here <class 'cupy.ndarray'> complex64
# 14
# Here <class 'cupy.ndarray'> complex64
# 15
# Here <class 'cupy.ndarray'> complex64
# 16
# Here <class 'cupy.ndarray'> complex64
# 17
# Here <class 'cupy.ndarray'> complex64
# 18
# Here <class 'cupy.ndarray'> complex64
# 19
# Here <class 'cupy.ndarray'> complex64
# 20
# Here <class 'cupy.ndarray'> complex64
# 21
# Here <class 'cupy.ndarray'> complex64
# 22
# Here <class 'cupy.ndarray'> complex64
# 23
# Here <class 'cupy.ndarray'> complex64
# 24
# Here <class 'cupy.ndarray'> complex64
# 25
# Here <class 'cupy.ndarray'> complex64
# 26
# Here <class 'cupy.ndarray'> complex64
# 27
# Here <class 'cupy.ndarray'> complex64
# 28
# Here <class 'cupy.ndarray'> complex64
# 29
# Here <class 'cupy.ndarray'> complex64
# end of loop, memory used, and total/1e9: 0.000635904 0.001050112
# normalized by data.nbytes memory used and total normalized: 9.703125 16.0234375
# ----
# total time: 1.1144134746864438
# {'Overlap': 0, 'Split': 0, 'Prox_data': 0.0034038606099784374, 'Data_prox_tot': 0.41564646223559976, 'Propagate': 0.40523193683475256, 'mse_data': 0.006944295018911362, 'Gramiam': 3.2582320272922516e-05, 'Gramiam_completion': 0.00020235823467373848, 'Precondition': 0, 'Eigensolver': 0.3864922556094825, 'Sync_setup': 7.70343467593193e-06, 'fd': 0}
# total time operators benchmarked: 1.2179614542983472
# after normalization
# {'Overlap': 0.0, 'Split': 0.0, 'Prox_data': 0.0027947194863727114, 'Data_prox_tot': 0.34126405295399814, 'Propagate': 0.3327132688843603, 'mse_data': 0.005701572077181938, 'Gramiam': 2.6751520056677652e-05, 'Gramiam_completion': 0.00016614502368657847, 'Precondition': 0.0, 'Eigensolver': 0.3173271651951711, 'Sync_setup': 6.324859172468463e-06, 'fd': 0.0}
# solver timers:
#  {'solver_tot': 1.1143049616366625, 'solver_loop': 0.9772706520743668, 'ProxD': 0.4261028068140149, 'Overlap': 0.006404793821275234, 'Sync': 0.5167570854537189, 'illuminate&split': 0.0019434629939496517, 'refine_illumination': 7.996801286935806e-06, 'mse_step': 0.007438262924551964, 'mse_truth': 0.014791483990848064, 'copies': 0.0017570145428180695, 'loop_intrnl': 0.9753460227511823, 'solver_final': 0.005111267790198326, 'solver_init': 0.13191981287673116}
# solver timers after normalization by 0.9772706520743668 :
#  {'solver_tot': 1.140221451725195, 'solver_loop': 1.0, 'ProxD': 0.4360131002701901, 'Overlap': 0.006553756431424948, 'Sync': 0.5287758149258283, 'illuminate&split': 0.0019886640306085454, 'refine_illumination': 8.182790785706801e-06, 'mse_step': 0.007611261945463537, 'mse_truth': 0.015135504130254477, 'copies': 0.0017978791638617291, 'loop_intrnl': 0.9980306076734227, 'solver_final': 0.005230145588992247, 'solver_init': 0.13498800214323076}
# mse timings: 0.029691061094629375
# ops timings: 0.446361582686871
# solver timers after normalization by total prox ops 0.446361582686871 :
#  {'solver_tot': 2.5544793637069714, 'solver_loop': 2.2403361731547453, 'ProxD': 0.9768159205046539, 'Overlap': 0.014682617603366869, 'Sync': 1.184635585667712, 'illuminate&split': 0.00445527596402404, 'refine_illumination': 1.8332202194576288e-05, 'mse_step': 0.01705178545977812, 'mse_truth': 0.033908617401942155, 'copies': 0.00402785372576064, 'loop_intrnl': 2.2359240722863807, 'solver_final': 0.011717284353885062, 'solver_init': 0.3024185041433702}
# solver tot (seconds) : 1.1143049616366625 loop: 0.9772706520743668 seconds
# proxD : 43.60131002701901 %
# Overlap : 0.6553756431424947 %
# illuminate and split : 0.19886640306085454 %
# mse: 2.9852571416512106 %
# proxD (propagate(ffts), mse, prox)%: (97.49437891403393, 1.67072155060835, 0.8189316929754201)

# %%
# %run ptycho_reconstruct.py
# Out:
# using GPU
# loaded data, memory used, and total: 80896 82432
# normalized by data.nbytes memory used and total normalized: 1.234375 1.2578125
# data size 65536
# ----
# Split and Overlap, memory used, and total: 80896 82432
# normalized by data.nbytes memory used and total normalized: 1.234375 1.2578125
# data size 65536
# ----
# Hello 1520
# Hellow 1584
# geometry: img size: (37, 37) frames: (16, 16, 64)
# not refining illumination, starting with good one, maxiter: 30
# start AP memory used, and total: 257536 490496
# normalized by data.nbytes memory used and total normalized: 3.9296875 7.484375
# data size 65536
# ----
# after Prox_data, memory used, and total: 259072 621568
# normalized by data.nbytes memory used and total normalized: 3.953125 9.484375
# ----
# after frames initial, memory used, and total: 390144 752640
# normalized by data.nbytes memory used and total normalized: 5.953125 11.484375
# ----
# !!!frames_norm (7.402797+0j) (7.402797+0j)
# start loop, memory used, and total: 534016 883712
# normalized by data.nbytes memory used and total normalized: 8.1484375 13.484375
# ----
# 0
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 4.4631392e-07
# Here <class 'cupy.ndarray'> complex64
# 1
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 5.530208e-07
# Here <class 'cupy.ndarray'> complex64
# 2
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 6.8505955e-07
# Here <class 'cupy.ndarray'> complex64
# 3
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 6.0506153e-07
# Here <class 'cupy.ndarray'> complex64
# 4
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 4.2997638e-07
# Here <class 'cupy.ndarray'> complex64
# 5
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 9.0991387e-07
# Here <class 'cupy.ndarray'> complex64
# 6
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 3.6279627e-07
# Here <class 'cupy.ndarray'> complex64
# 7
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 5.656282e-07
# Here <class 'cupy.ndarray'> complex64
# 8
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 7.634179e-07
# Here <class 'cupy.ndarray'> complex64
# 9
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 4.4629115e-07
# Here <class 'cupy.ndarray'> complex64
# 10
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 4.2583943e-07
# Here <class 'cupy.ndarray'> complex64
# 11
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 4.3812338e-07
# Here <class 'cupy.ndarray'> complex64
# 12
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 2.6010846e-07
# Here <class 'cupy.ndarray'> complex64
# 13
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 3.0420662e-07
# Here <class 'cupy.ndarray'> complex64
# 14
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 3.5287667e-07
# Here <class 'cupy.ndarray'> complex64
# 15
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 3.1001335e-07
# Here <class 'cupy.ndarray'> complex64
# 16
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 2.3116307e-07
# Here <class 'cupy.ndarray'> complex64
# 17
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 1.6896325e-07
# Here <class 'cupy.ndarray'> complex64
# 18
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 1.6557244e-08
# Here <class 'cupy.ndarray'> complex64
# 19
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 6.0944984e-08
# Here <class 'cupy.ndarray'> complex64
# 20
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 1.2794231e-08
# Here <class 'cupy.ndarray'> complex64
# 21
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 1.1231894e-08
# Here <class 'cupy.ndarray'> complex64
# 22
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 1.0707345e-08
# Here <class 'cupy.ndarray'> complex64
# 23
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 1.1938388e-08
# Here <class 'cupy.ndarray'> complex64
# 24
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 1.4083462e-08
# Here <class 'cupy.ndarray'> complex64
# 25
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 1.1984453e-08
# Here <class 'cupy.ndarray'> complex64
# 26
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 1.1822736e-08
# Here <class 'cupy.ndarray'> complex64
# 27
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 1.4282702e-08
# Here <class 'cupy.ndarray'> complex64
# 28
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 1.257195e-08
# Here <class 'cupy.ndarray'> complex64
# 29
# same_kernel 0.0
# <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> int64 <class 'cupy.ndarray'> complex64
# same?? 1.3217084e-08
# Here <class 'cupy.ndarray'> complex64
# end of loop, memory used, and total/1e9: 0.000678912 0.001342464
# normalized by data.nbytes memory used and total normalized: 10.359375 20.484375
# ----
# total time: 82.31710896501318
# {'Overlap': 0, 'Split': 0, 'Prox_data': 0.004341940861195326, 'Data_prox_tot': 0.4178973799571395, 'Propagate': 0.40672450652346015, 'mse_data': 0.006756925489753485, 'Gramiam': 2.664823800791055, 'Gramiam_completion': 0.016098614316433668, 'Precondition': 0, 'Eigensolver': 1.009138597175479, 'Sync_setup': 1.0468065738677979e-05, 'fd': 0}
# total time operators benchmarked: 4.525792233180255
# after normalization
# {'Overlap': 0.0, 'Split': 0.0, 'Prox_data': 0.0009593769747897293, 'Data_prox_tot': 0.09233684588819156, 'Propagate': 0.08986813480778294, 'mse_data': 0.0014929818121600829, 'Gramiam': 0.588808249140172, 'Gramiam_completion': 0.0035570820503886104, 'Precondition': 0.0, 'Eigensolver': 0.22297501634677594, 'Sync_setup': 2.3129797390902573e-06, 'fd': 0.0}
# solver timers:
#  {'solver_tot': 82.31699586613104, 'solver_loop': 82.1745508890599, 'ProxD': 0.4279949711635709, 'Overlap': 0.0103279915638268, 'Sync': 81.70823283167556, 'illuminate&split': 0.0033558388240635395, 'refine_illumination': 2.5711022317409515e-05, 'mse_step': 0.007775371428579092, 'mse_truth': 0.0128015810623765, 'copies': 0.001792099792510271, 'loop_intrnl': 82.17247939994559, 'solver_final': 0.009347181767225266, 'solver_init': 0.13309216126799583}
# solver timers after normalization by 82.1745508890599 :
#  {'solver_tot': 1.0017334439376913, 'solver_loop': 1.0, 'ProxD': 0.005208363982924437, 'Overlap': 0.0001256835778484527, 'Sync': 0.9943252740375315, 'illuminate&split': 4.0837933250089847e-05, 'refine_illumination': 3.12883028130215e-07, 'mse_step': 9.462018769139687e-05, 'mse_truth': 0.0001557852269817614, 'copies': 2.180845253331172e-05, 'loop_intrnl': 0.9999747915979837, 'solver_final': 0.00011374788990139378, 'solver_init': 0.001619627485980148}
# mse timings: 0.007007330904426643
# ops timings: 0.005397006829584422
# solver timers after normalization by total prox ops 0.005397006829584422 :
#  {'solver_tot': 185.6090747275979, 'solver_loop': 185.2878885604452, 'ProxD': 0.9650467652503395, 'Overlap': 0.02328764476626214, 'Sync': 184.23643056870026, 'illuminate&split': 0.007566774425081546, 'refine_illumination': 5.797343564864592e-05, 'mse_step': 0.017531974792531952, 'mse_truth': 0.028865115776360264, 'copies': 0.00404084212266802, 'loop_intrnl': 185.2832177488616, 'solver_final': 0.02107610634803524, 'solver_init': 0.3000973571317237}
# solver tot (seconds) : 82.31699586613104 loop: 82.1745508890599 seconds
# proxD : 0.5208363982924437 %
# Overlap : 0.01256835778484527 %
# illuminate and split : 0.004083793325008985 %
# mse: 0.03326319120090026 %
# proxD (propagate(ffts), mse, prox)%: (97.326407398193, 1.6168863012365597, 1.0389969091552202)
