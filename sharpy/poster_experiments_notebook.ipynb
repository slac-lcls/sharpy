# %% [markdown]
# Generate data:
# Setup:16 by 16 frame size, step size 5.
# Number of frames: 8x8,16x16,32x32,64x64
# Output: "poster_8x8.h5" etc.c

# %%
# %run ptycho_simulate.py
# Out:
# type0 <class 'cupy.ndarray'> int64

# %% [markdown]
# Experiment1: Convergence rate versus number of frames

# %%
fname_in = "poster_16x16.h5"
# %run -i poster_experiment.py
# Out:
# using GPU
# loaded data, memory used, and total: 320000 321536
# normalized by data.nbytes memory used and total normalized: 1.220703125 1.2265625
# data size 262144
# ----
# Split and Overlap, memory used, and total: 320000 321536
# normalized by data.nbytes memory used and total normalized: 1.220703125 1.2265625
# data size 262144
# ----
# geometry: img size: (77, 77) frames: (16, 16, 256)
# not refining illumination, starting with good one, maxiter: 400
# start AP memory used, and total: 999424 3387392
# normalized by data.nbytes memory used and total normalized: 3.8125 12.921875
# data size 262144
# ----
# after Prox_data, memory used, and total: 1002496 3387392
# normalized by data.nbytes memory used and total normalized: 3.82421875 12.921875
# ----
# after frames initial, memory used, and total: 1526784 3387392
# normalized by data.nbytes memory used and total normalized: 5.82421875 12.921875
# ----
# start loop, memory used, and total: 1581568 3387392
# ...

# %%
fname_in = "poster_32x32.h5"
# %run -i poster_experiment.py
# Out:
# using GPU
# loaded data, memory used, and total: 8168960 44274176
# normalized by data.nbytes memory used and total normalized: 7.79052734375 42.22314453125
# data size 1048576
# ----
# Split and Overlap, memory used, and total: 8168960 44274176
# normalized by data.nbytes memory used and total normalized: 7.79052734375 42.22314453125
# data size 1048576
# ----
# geometry: img size: (157, 157) frames: (16, 16, 1024)
# not refining illumination, starting with good one, maxiter: 400
# start AP memory used, and total: 8168960 52662784
# normalized by data.nbytes memory used and total normalized: 7.79052734375 50.22314453125
# data size 1048576
# ----
# after Prox_data, memory used, and total: 8178176 52662784
# normalized by data.nbytes memory used and total normalized: 7.79931640625 50.22314453125
# ----
# after frames initial, memory used, and total: 10275328 52662784
# normalized by data.nbytes memory used and total normalized: 9.79931640625 50.22314453125
# ----
# ...

# %%
fname_in = "poster_64x64.h5"
# %run -i poster_experiment.py
# Out:
# using GPU
# loaded data, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# Split and Overlap, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# geometry: img size: (317, 317) frames: (16, 16, 4096)
# not refining illumination, starting with good one, maxiter: 400
# start AP memory used, and total: 15729152 693016576
# normalized by data.nbytes memory used and total normalized: 3.7501220703125 165.22802734375
# data size 4194304
# ----
# after Prox_data, memory used, and total: 15762944 693016576
# normalized by data.nbytes memory used and total normalized: 3.7581787109375 165.22802734375
# ----
# after frames initial, memory used, and total: 24151552 693016576
# normalized by data.nbytes memory used and total normalized: 5.7581787109375 165.22802734375
# ----
# ...

# %% [markdown]
# Next experiment test on
# 1. convergence rate for different sync interval
# 2. Time/iterations to reach the same level of accuracy

# %% [markdown]
# The following experiments is for the time vs frequency table.
# Set maxiter = 8000 for no sync

# %%
fname_in = "poster_64x64.h5"
# %run -i poster_experiment_SyncN.py
# Out:
# using GPU
# loaded data, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# Split and Overlap, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# geometry: img size: (317, 317) frames: (16, 16, 4096)
# not refining illumination, starting with good one, maxiter: 200
# start AP memory used, and total: 15729152 693016576
# normalized by data.nbytes memory used and total normalized: 3.7501220703125 165.22802734375
# data size 4194304
# ----
# after Prox_data, memory used, and total: 15762944 693016576
# normalized by data.nbytes memory used and total normalized: 3.7581787109375 165.22802734375
# ----
# after frames initial, memory used, and total: 24151552 693016576
# normalized by data.nbytes memory used and total normalized: 5.7581787109375 165.22802734375
# ----
# ...

# %%
fname_in = "poster_32x32.h5"
# %run -i poster_experiment_SyncN.py
# Out:
# using GPU
# loaded data, memory used, and total: 1281024 1282560
# normalized by data.nbytes memory used and total normalized: 1.2216796875 1.22314453125
# data size 1048576
# ----
# Split and Overlap, memory used, and total: 1281024 1282560
# normalized by data.nbytes memory used and total normalized: 1.2216796875 1.22314453125
# data size 1048576
# ----
# geometry: img size: (157, 157) frames: (16, 16, 1024)
# not refining illumination, starting with good one, maxiter: 400
# start AP memory used, and total: 4148224 36934144
# normalized by data.nbytes memory used and total normalized: 3.9560546875 35.22314453125
# data size 1048576
# ----
# after Prox_data, memory used, and total: 4157440 36934144
# normalized by data.nbytes memory used and total normalized: 3.96484375 35.22314453125
# ----
# after frames initial, memory used, and total: 6254592 36934144
# normalized by data.nbytes memory used and total normalized: 5.96484375 35.22314453125
# ----
# ...

# %%
fname_in = "poster_16x16.h5"
# %run -i poster_experiment_SyncN.py
# Out:
# using GPU
# loaded data, memory used, and total: 320000 321536
# normalized by data.nbytes memory used and total normalized: 1.220703125 1.2265625
# data size 262144
# ----
# Split and Overlap, memory used, and total: 320000 321536
# normalized by data.nbytes memory used and total normalized: 1.220703125 1.2265625
# data size 262144
# ----
# geometry: img size: (77, 77) frames: (16, 16, 256)
# not refining illumination, starting with good one, maxiter: 400
# start AP memory used, and total: 1047040 3387392
# normalized by data.nbytes memory used and total normalized: 3.994140625 12.921875
# data size 262144
# ----
# after Prox_data, memory used, and total: 1050112 3387392
# normalized by data.nbytes memory used and total normalized: 4.005859375 12.921875
# ----
# after frames initial, memory used, and total: 1574400 3387392
# normalized by data.nbytes memory used and total normalized: 6.005859375 12.921875
# ----
# start loop, memory used, and total: 1629184 3387392
# ...

# %%
fname_in = "poster_8x8.h5"
# %run -i poster_experiment_SyncN.py
# Out:
# using GPU
# loaded data, memory used, and total: 80896 82432
# normalized by data.nbytes memory used and total normalized: 1.234375 1.2578125
# data size 65536
# ----
# Split and Overlap, memory used, and total: 80896 82432
# normalized by data.nbytes memory used and total normalized: 1.234375 1.2578125
# data size 65536
# ----
# geometry: img size: (37, 37) frames: (16, 16, 64)
# not refining illumination, starting with good one, maxiter: 400
# start AP memory used, and total: 268800 479744
# normalized by data.nbytes memory used and total normalized: 4.1015625 7.3203125
# data size 65536
# ----
# after Prox_data, memory used, and total: 270336 610816
# normalized by data.nbytes memory used and total normalized: 4.125 9.3203125
# ----
# after frames initial, memory used, and total: 401408 741888
# normalized by data.nbytes memory used and total normalized: 6.125 11.3203125
# ----
# start loop, memory used, and total: 419840 741888
# ...

# %% [markdown]
# The next experiment is for the convergence plot for the frequency test. Set maxiter = 400 for both sync & no sync.

# %%
fname_in = "poster_64x64.h5"
# %run -i poster_experiment_SyncN.py
# Out:
# using GPU
# loaded data, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# Split and Overlap, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# geometry: img size: (317, 317) frames: (16, 16, 4096)
# not refining illumination, starting with good one, maxiter: 400
# start AP memory used, and total: 16533504 458135552
# normalized by data.nbytes memory used and total normalized: 3.94189453125 109.22802734375
# data size 4194304
# ----
# after Prox_data, memory used, and total: 16567296 458135552
# normalized by data.nbytes memory used and total normalized: 3.949951171875 109.22802734375
# ----
# after frames initial, memory used, and total: 24955904 458135552
# normalized by data.nbytes memory used and total normalized: 5.949951171875 109.22802734375
# ----
# ...

# %%
fname_in = "poster_64x64.h5"
# %run -i poster_experiment_SyncN.py

# %%
plt. savefig('sync_freq.png')

# %% [markdown]
# Differente type of eigensolver
# 1. Percentage of time used to reach same level of mse accuracy
# 2. convergence plot

# %%
fname_in = "poster_32x32.h5"
# %run -i poster_experiment_Eig.py
# Out:
# using GPU
# loaded data, memory used, and total: 1281024 1282560
# normalized by data.nbytes memory used and total normalized: 1.2216796875 1.22314453125
# data size 1048576
# ----
# Split and Overlap, memory used, and total: 1281024 1282560
# normalized by data.nbytes memory used and total normalized: 1.2216796875 1.22314453125
# data size 1048576
# ----
# geometry: img size: (157, 157) frames: (16, 16, 1024)
# not refining illumination, starting with good one, maxiter: 400
# start AP memory used, and total: 3950592 44274176
# normalized by data.nbytes memory used and total normalized: 3.767578125 42.22314453125
# data size 1048576
# ----
# after Prox_data, memory used, and total: 3959808 44274176
# normalized by data.nbytes memory used and total normalized: 3.7763671875 42.22314453125
# ----
# after frames initial, memory used, and total: 6056960 44274176
# normalized by data.nbytes memory used and total normalized: 5.7763671875 42.22314453125
# ----
# ...

# %%
# %run poster_experiment_Eig.py
# Out:
# using GPU
# loaded data, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# Split and Overlap, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# geometry: img size: (317, 317) frames: (16, 16, 4096)
# not refining illumination, starting with good one, maxiter: 100
# start AP memory used, and total: 15729152 693016576
# normalized by data.nbytes memory used and total normalized: 3.7501220703125 165.22802734375
# data size 4194304
# ----
# after Prox_data, memory used, and total: 15762944 693016576
# normalized by data.nbytes memory used and total normalized: 3.7581787109375 165.22802734375
# ----
# after frames initial, memory used, and total: 24151552 693016576
# normalized by data.nbytes memory used and total normalized: 5.7581787109375 165.22802734375
# ----
# ...

# %%
fname_in = "poster_64x64.h5"
# %run -i poster_experiment_Eig.py
# Out:
# using GPU
# loaded data, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# Split and Overlap, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# geometry: img size: (317, 317) frames: (16, 16, 4096)
# not refining illumination, starting with good one, maxiter: 10
# Name                Shape                Bytes            Type
# ...
#
# data                4096 x 16 x 16       4194304          float32
# illumination        16 x 16              2048             complex64
# img_initial         317 x 317            803912           complex64
# translations        4096 x 1 x 1         65536            complex128
# translations_x      4096 x 1 x 1         32768            int64
# translations_y      4096 x 1 x 1         32768            int64
# ...

# %%
# %run ptycho_simulate.py
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Git/sharpy/sharpy/ptycho_simulate.py:5
#       1 # -*- coding: utf-8 -*-
#       2 #!/cds/home/y/yn754/anaconda3/envs/sharpy-env/bin/python
#       4 import numpy as np
# ----> 5 import cupy as cp
#       6 import h5py
#       8 from Operators import Split_plan
#
# File ~/anaconda3/envs/sharpy-env/py311/lib/python3.11/site-packages/cupy/__init__.py:17
#      13 _environment._preload_library('nccl')  # NOQA
#      16 try:
# ---> 17     from cupy import _core  # NOQA
#      18 except ImportError as exc:
#      19     raise ImportError(f'''
#      20 ================================================================
#      21 {_environment._diagnose_import_error()}
#    (...)
#      25 ================================================================
#      26 ''') from exc
#
# ...

# %%
fname_in = "poster_64x64.h5"
# %run -i ptycho_reconstruct.py
# Out:
# using GPU
# loaded data, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# Split and Overlap, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# geometry: img size: (317, 317) frames: (16, 16, 4096)
# not refining illumination, starting with good one, maxiter: 2
# start AP memory used, and total: 17294336 693016576
# normalized by data.nbytes memory used and total normalized: 4.123291015625 165.22802734375
# data size 4194304
# ----
# after Prox_data, memory used, and total: 17328128 693016576
# normalized by data.nbytes memory used and total normalized: 4.13134765625 165.22802734375
# ----
# after frames initial, memory used, and total: 25716736 693016576
# normalized by data.nbytes memory used and total normalized: 6.13134765625 165.22802734375
# ----
# ...

# %%
fname_in = 'poster_8x8.h5'
# %run -i poster_experiment_Eig.py
# Out:
# using GPU
# loaded data, memory used, and total: 80896 82432
# normalized by data.nbytes memory used and total normalized: 1.234375 1.2578125
# data size 65536
# ----
# Split and Overlap, memory used, and total: 80896 82432
# normalized by data.nbytes memory used and total normalized: 1.234375 1.2578125
# data size 65536
# ----
# geometry: img size: (37, 37) frames: (16, 16, 64)
# not refining illumination, starting with good one, maxiter: 1000
# start AP memory used, and total: 281600 490496
# normalized by data.nbytes memory used and total normalized: 4.296875 7.484375
# data size 65536
# ----
# after Prox_data, memory used, and total: 283136 621568
# normalized by data.nbytes memory used and total normalized: 4.3203125 9.484375
# ----
# after frames initial, memory used, and total: 414208 752640
# normalized by data.nbytes memory used and total normalized: 6.3203125 11.484375
# ----
# start loop, memory used, and total: 442368 752640
# ...

# %%
fname_in = 'poster_16x16.h5'
# %run -i poster_experiment_Eig.py
# Out:
# using GPU
# loaded data, memory used, and total: 320000 321536
# normalized by data.nbytes memory used and total normalized: 1.220703125 1.2265625
# data size 262144
# ----
# Split and Overlap, memory used, and total: 320000 321536
# normalized by data.nbytes memory used and total normalized: 1.220703125 1.2265625
# data size 262144
# ----
# geometry: img size: (77, 77) frames: (16, 16, 256)
# not refining illumination, starting with good one, maxiter: 1000
# start AP memory used, and total: 1096192 3008512
# normalized by data.nbytes memory used and total normalized: 4.181640625 11.4765625
# data size 262144
# ----
# after Prox_data, memory used, and total: 1099264 3008512
# normalized by data.nbytes memory used and total normalized: 4.193359375 11.4765625
# ----
# after frames initial, memory used, and total: 1623552 3008512
# normalized by data.nbytes memory used and total normalized: 6.193359375 11.4765625
# ----
# start loop, memory used, and total: 1688064 3008512
# ...

# %%
fname_in = 'poster_32x32.h5'
# %run -i poster_experiment_Eig.py
# Out:
# using GPU
# loaded data, memory used, and total: 1281024 1282560
# normalized by data.nbytes memory used and total normalized: 1.2216796875 1.22314453125
# data size 1048576
# ----
# Split and Overlap, memory used, and total: 1281024 1282560
# normalized by data.nbytes memory used and total normalized: 1.2216796875 1.22314453125
# data size 1048576
# ----
# geometry: img size: (157, 157) frames: (16, 16, 1024)
# not refining illumination, starting with good one, maxiter: 1000
# start AP memory used, and total: 4340224 44274176
# normalized by data.nbytes memory used and total normalized: 4.13916015625 42.22314453125
# data size 1048576
# ----
# after Prox_data, memory used, and total: 4349440 44274176
# normalized by data.nbytes memory used and total normalized: 4.14794921875 42.22314453125
# ----
# after frames initial, memory used, and total: 6446592 44274176
# normalized by data.nbytes memory used and total normalized: 6.14794921875 42.22314453125
# ----
# ...

# %%
fname_in = 'poster_64x64.h5'
# %run -i poster_experiment_Eig.py
# Out:
# using GPU
# loaded data, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# Split and Overlap, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# geometry: img size: (317, 317) frames: (16, 16, 4096)
# not refining illumination, starting with good one, maxiter: 4000
# start AP memory used, and total: 17294336 693016576
# normalized by data.nbytes memory used and total normalized: 4.123291015625 165.22802734375
# data size 4194304
# ----
# after Prox_data, memory used, and total: 17328128 693016576
# normalized by data.nbytes memory used and total normalized: 4.13134765625 165.22802734375
# ----
# after frames initial, memory used, and total: 25716736 693016576
# normalized by data.nbytes memory used and total normalized: 6.13134765625 165.22802734375
# ----
# ...

# %%
fname_in = 'poster_64x64.h5'
# %run -i ptycho_reconstruct.py
# Out:
# using GPU
# loaded data, memory used, and total: 25718784 693016576
# normalized by data.nbytes memory used and total normalized: 6.1318359375 165.22802734375
# data size 4194304
# ----
# Split and Overlap, memory used, and total: 25718784 693016576
# normalized by data.nbytes memory used and total normalized: 6.1318359375 165.22802734375
# data size 4194304
# ----
# geometry: img size: (317, 317) frames: (16, 16, 4096)
# not refining illumination, starting with good one, maxiter: 2
# start AP memory used, and total: 26523136 827234304
# normalized by data.nbytes memory used and total normalized: 6.3236083984375 197.22802734375
# data size 4194304
# ----
# after Prox_data, memory used, and total: 26556928 827234304
# normalized by data.nbytes memory used and total normalized: 6.3316650390625 197.22802734375
# ----
# after frames initial, memory used, and total: 34945536 827234304
# normalized by data.nbytes memory used and total normalized: 8.3316650390625 197.22802734375
# ----
# ...

# %%
fname_in = 'poster_64x64.h5'
# %run -i ptycho_reconstruct.py
# Out:
# using GPU
# loaded data, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# Split and Overlap, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# geometry: img size: (317, 317) frames: (16, 16, 4096)
# not refining illumination, starting with good one, maxiter: 2
# start AP memory used, and total: 17294336 693016576
# normalized by data.nbytes memory used and total normalized: 4.123291015625 165.22802734375
# data size 4194304
# ----
# after Prox_data, memory used, and total: 17328128 693016576
# normalized by data.nbytes memory used and total normalized: 4.13134765625 165.22802734375
# ----
# after frames initial, memory used, and total: 25716736 693016576
# normalized by data.nbytes memory used and total normalized: 6.13134765625 165.22802734375
# ----
# ...

# %%
fname_in = 'poster_32x32.h5'
# %run -i poster_experiment.py
# Out:
# using GPU
# loaded data, memory used, and total: 1281024 1282560
# normalized by data.nbytes memory used and total normalized: 1.2216796875 1.22314453125
# data size 1048576
# ----
# Split and Overlap, memory used, and total: 1281024 1282560
# normalized by data.nbytes memory used and total normalized: 1.2216796875 1.22314453125
# data size 1048576
# ----
# geometry: img size: (157, 157) frames: (16, 16, 1024)
# not refining illumination, starting with good one, maxiter: 100
# start AP memory used, and total: 3950592 44274176
# normalized by data.nbytes memory used and total normalized: 3.767578125 42.22314453125
# data size 1048576
# ----
# after Prox_data, memory used, and total: 3959808 44274176
# normalized by data.nbytes memory used and total normalized: 3.7763671875 42.22314453125
# ----
# after frames initial, memory used, and total: 6056960 44274176
# normalized by data.nbytes memory used and total normalized: 5.7763671875 42.22314453125
# ----
# ...

# %%
fname_in = 'poster_128x128.h5'
# %run -i ptycho_reconstruct.py
# Out:
# using GPU
# loaded data, memory used, and total: 20550144 20569088
# normalized by data.nbytes memory used and total normalized: 1.224884033203125 1.22601318359375
# data size 16777216
# ----
# Split and Overlap, memory used, and total: 20550144 20569088
# normalized by data.nbytes memory used and total normalized: 1.224884033203125 1.22601318359375
# data size 16777216
# ----
# geometry: img size: (637, 637) frames: (16, 16, 16384)
# not refining illumination, starting with good one, maxiter: 50
# start AP memory used, and total: 66027520 7268326400
# normalized by data.nbytes memory used and total normalized: 3.935546875 433.22601318359375
# data size 16777216
# ----
# after Prox_data, memory used, and total: 66159616 7268326400
# normalized by data.nbytes memory used and total normalized: 3.94342041015625 433.22601318359375
# ----
# after frames initial, memory used, and total: 99714048 7268326400
# ...

# %%
# %run ptycho_simulate.py
# Out:
# ill
# type0 <class 'cupy.ndarray'> int64

# %% [markdown]
# Next experiment is plot pie chart for time taken
# 1. Pie1: nx = 32  # frame size, Dx = 5  # Step size,nnx= 128

# %%
fname_in = 'poster_large.h5'
# %run -i poster_experiment.py
# Out:
# using GPU
# loaded data, memory used, and total: 70887936 70906880
# normalized by data.nbytes memory used and total normalized: 1.0563125610351562 1.0565948486328125
# data size 67108864
# ----
# Split and Overlap, memory used, and total: 70887936 70906880
# normalized by data.nbytes memory used and total normalized: 1.0563125610351562 1.0565948486328125
# data size 67108864
# ----
# geometry: img size: (637, 637) frames: (32, 32, 16384)
# not refining illumination, starting with good one, maxiter: 400
# start AP memory used, and total: 213983744 7318664192
# normalized by data.nbytes memory used and total normalized: 3.1886062622070312 109.05659484863281
# data size 67108864
# ----
# after Prox_data, memory used, and total: 214115840 7318664192
# normalized by data.nbytes memory used and total normalized: 3.1905746459960938 109.05659484863281
# ----
# after frames initial, memory used, and total: 348333568 7318664192
# ...

# %%
fname_in = 'poster_64x64.h5'
# %run -i ptycho_reconstruct.py
# Out:
# using GPU
# loaded data, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# Split and Overlap, memory used, and total: 5131776 5150720
# normalized by data.nbytes memory used and total normalized: 1.2235107421875 1.22802734375
# data size 4194304
# ----
# geometry: img size: (317, 317) frames: (16, 16, 4096)
# not refining illumination, starting with good one, maxiter: 1
# start AP memory used, and total: 16533504 458135552
# normalized by data.nbytes memory used and total normalized: 3.94189453125 109.22802734375
# data size 4194304
# ----
# after Prox_data, memory used, and total: 16567296 458135552
# normalized by data.nbytes memory used and total normalized: 3.949951171875 109.22802734375
# ----
# after frames initial, memory used, and total: 24955904 458135552
# normalized by data.nbytes memory used and total normalized: 5.949951171875 109.22802734375
# ----
# ...
