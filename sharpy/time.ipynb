# %%
# %run ptycho_reconstruct.py
# Out:
# using GPU
# loaded data, memory used, and total: 315904 320000
# normalized by data.nbytes memory used and total normalized: 1.205078125 1.220703125
# data size 262144
# ----
# Split and Overlap, memory used, and total: 1126400 5829632
# normalized by data.nbytes memory used and total normalized: 4.296875 22.23828125
# data size 262144
# ----
# geometry: img size: (77, 77) frames: (16, 16, 256)
# not refining illumination, starting with good one, maxiter: 1
# start AP memory used, and total: 1515008 5829632
# normalized by data.nbytes memory used and total normalized: 5.779296875 22.23828125
# data size 262144
# ----
# after Prox_data, memory used, and total: 1516032 5829632
# normalized by data.nbytes memory used and total normalized: 5.783203125 22.23828125
# ----
# after frames initial, memory used, and total: 2564608 6878208
# normalized by data.nbytes memory used and total normalized: 9.783203125 26.23828125
# ----
# start loop, memory used, and total: 2851840 6878208
# ...

# %%
import cupy as cp
a = cp.random.randn(30000, 2000, dtype=cp.float64) + 1j * cp.random.randn(30000, 2000, dtype=cp.float64)
b = cp.random.randn(30000, 2000, dtype=cp.float64) + 1j * cp.random.randn(30000, 2000, dtype=cp.float64)

# %%
type(a.dtype)
# Out:
# numpy.dtype[complex128]

# %%
from timeit import default_timer as timer
t0 = timer()
cp.vdot(a,b)
timer()-t0
# Out:
# 0.0008460170356556773

# %%
import numpy as np
t0 = timer()
np.vdot(a,b)
timer()-t0
# Out:
# 0.0008919939864426851

# %%
ls
# Out:
# config.py*              ptycho_simulate.py*        Solvers.py*
# fft_plan.py*            ptycho_test_operators.py*  src/
# __init__.py             __pycache__/               sync_noise_operator.py
# noise_analysis.ipynb    simulation.h5              sync_noise_test.py
# Operators.py*           simulation_hc.h5           tests/
# ptycho_reconstruct.py*  single_sync.py             time.ipynb

# %%
# %run ptycho_simulate.py
# Out:
# type0 <class 'cupy.ndarray'> int64

# %%
# %run ptycho_reconstruct.py
# Out:
# using GPU
# loaded data, memory used, and total: 320000 321536
# normalized by data.nbytes memory used and total normalized: 1.220703125 1.2265625
# data size 262144
# ----
# Split and Overlap, memory used, and total: 1130496 5833216
# normalized by data.nbytes memory used and total normalized: 4.3125 22.251953125
# data size 262144
# ----
# !!!!! <class 'numpy.dtypes.Int64DType'>
# !!!!! <class 'numpy.dtypes.Int64DType'>
# geometry: img size: (77, 77) frames: (16, 16, 256)
# not refining illumination, starting with good one, maxiter: 30
# start AP memory used, and total: 1844736 5833216
# normalized by data.nbytes memory used and total normalized: 7.037109375 22.251953125
# data size 262144
# ----
# after Prox_data, memory used, and total: 1845760 5833216
# normalized by data.nbytes memory used and total normalized: 7.041015625 22.251953125
# ----
# after frames initial, memory used, and total: 2370048 5833216
# ...

# %%
# !export CUDA_PATH=/cds/home/y/yn754/anaconda3/envs/sharpy-env/py311/
# !export LD_LIBRARY_PATH=$CUDA_PATH/lib:$LD_LIBRARY_PATH

# %%
# !which nvcc
# Out:
# which: no nvcc in (/cds/sw/ds/dm/conda/envs/jhub-2.0.0/bin:/sbin/:/usr/bin/:/bin)

# %%
pwd
# Out:
# '/cds/home/y/yn754/Git/sharpy/sharpy'

# %%
# !export PATH=/cds/home/y/yn754/anaconda3/envs/jhub-2.0.0

# %%
# !echo $PATH
# Out:
# /cds/sw/ds/dm/conda/envs/jhub-2.0.0/bin:/sbin/:/usr/bin/:/bin

# %%
# !nvidia-smi
# Out:
# Thu Jul 20 10:18:24 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 470.57.02    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:82:00.0 Off |                  N/A |
# | 23%   30C    P8     8W / 250W |   2616MiB / 11178MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
print(cp.__version__)
# Out:
# 12.1.0

# %%
conda list
# Out:
# # packages in environment at /cds/home/y/yn754/anaconda3/envs/sharpy-env/py311:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# alsa-lib                  1.2.8                h166bdaf_0    conda-forge
# asttokens                 2.0.5              pyhd3eb1b0_0    anaconda
# attr                      2.5.1                h166bdaf_1    conda-forge
# backcall                  0.2.0              pyhd3eb1b0_0    anaconda
# brotli                    1.0.9                h166bdaf_9    conda-forge
# brotli-bin                1.0.9                h166bdaf_9    conda-forge
# brotli-python             1.0.9           py311ha362b79_9    conda-forge
# bzip2                     1.0.8                h7f98852_4    conda-forge
# c-ares                    1.19.1               hd590300_0    conda-forge
# ...

# %%
cd /usr/local/cuda/include/cub
# Out:
# /usr/local/cuda-11.3/targets/x86_64-linux/include/cub

# %%
pwd
# Out:
# '/usr/local/cuda-11.3/targets/x86_64-linux/include/cub'

# %%
ls
# Out:
# agent/      device/    util_allocator.cuh    util_deprecated.cuh  util_type.cuh
# block/      grid/      util_arch.cuh         util_device.cuh      version.cuh
# cmake/      host/      util_compiler.cuh     util_macro.cuh       warp/
# config.cuh  iterator/  util_cpp_dialect.cuh  util_namespace.cuh
# cub.cuh     thread/    util_debug.cuh        util_ptx.cuh

# %%
pwd
# Out:
# '/cds/home/y/yn754'

# %%
ls
# Out:
# anaconda3/  examplePython3/  Untitled1.ipynb  Untitled4.ipynb  workshop.ipynb
# Backup/     Git/             Untitled2.ipynb  Untitled5.ipynb
# Download/   sharpy.ipynb     Untitled3.ipynb  Untitled.ipynb

# %%
cd anaconda3
# Out:
# /cds/home/y/yn754/anaconda3

# %%
cd envs/sharpy-env/py311
# Out:
# /cds/home/y/yn754/anaconda3/envs/sharpy-env/py311

# %%
cd bin
# Out:
# bin/                            lib/               qml/
# cmake/                          libexec/           README
# compiler_compat/                libnvvp/           samples/
# compute-sanitizer/              LICENSE            sbin/
# conda-meta/                     man/               share/
# CUDA_Toolkit_Release_Notes.txt  mkspecs/           src/
# doc/                            nsight-compute/    ssl/
# DOCS                            nsightee_plugins/  tools/
# etc/                            nvml/              translations/
# EULA.txt                        nvvm/              var/
# extras/                         phrasebooks/       x86_64-conda_cos6-linux-gnu/
# fonts/                          pkg-config/        x86_64-conda-linux-gnu/
# include/                        plugins/

# %%
conda list
# Out:
# # packages in environment at /cds/home/y/yn754/anaconda3/envs/sharpy-env/py311:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# asttokens                 2.0.5              pyhd3eb1b0_0    anaconda
# backcall                  0.2.0              pyhd3eb1b0_0    anaconda
# bzip2                     1.0.8                h7f98852_4    conda-forge
# c-ares                    1.19.1               hd590300_0    conda-forge
# ca-certificates           2023.5.7             hbcca054_0    conda-forge
# cached-property           1.5.2                hd8ed1ab_1    conda-forge
# cached_property           1.5.2              pyha770c72_1    conda-forge
# comm                      0.1.3              pyhd8ed1ab_0    conda-forge
# cuda-cccl                 12.1.55                       0    nvidia/label/cuda-12.1.0
# ...

# %%
conda install cupy
# Out:
# ...
# /
# Note: you may need to restart the kernel to use updated packages.

# %%
# !which nvrtc
# Out:
# which: no nvrtc in (/cds/sw/ds/dm/conda/envs/jhub-2.0.0/bin:/sbin/:/usr/bin/:/bin)

# %%
# !which nvidia-smi
# Out:
# /usr/bin/nvidia-smi

# %%
import matplotlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import matplotlib
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !which cuda
# Out:
# which: no cuda in (/cds/sw/ds/dm/conda/envs/jhub-2.0.0/bin:/sbin/:/usr/bin/:/bin)

# %%
cp.show_config()
# Out:
# OS                           : Linux-3.10.0-1160.36.2.el7.x86_64-x86_64-with-glibc2.17
# Python Version               : 3.11.4
# CuPy Version                 : 12.1.0
# CuPy Platform                : NVIDIA CUDA
# NumPy Version                : 1.25.1
# SciPy Version                : 1.11.1
# Cython Build Version         : 0.29.35
# Cython Runtime Version       : None
# CUDA Root                    : /usr/local/cuda
# nvcc PATH                    : /usr/local/cuda/bin/nvcc
# CUDA Build Version           : 11020
# CUDA Driver Version          : 11040
# CUDA Runtime Version         : 11080
# cuBLAS Version               : (available)
# cuFFT Version                : 10900
# cuRAND Version               : 10300
# cuSOLVER Version             : (11, 4, 1)
# cuSPARSE Version             : (available)
# NVRTC Version                : (11, 8)
# Thrust Version               : 101000
# CUB Build Version            : 101000
# Jitify Build Version         : 4e18da2
# ...
